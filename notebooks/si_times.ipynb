# %%
import spikeinterface.extractors as se
import spikeinterface as si
import pipeline_tdt as p
from pipeline_tdt import load_and_preprocess_si_recording
from pathlib import Path
import tdt

# %%
from pipeline_tdt import run_sorting

# %%
def run_pipeline(
    # paths and data
    tdt_folder_paths,
    output_dir,
    store="NNXr",
    nchans=16,
    t_end=None,
    # PRepro
    prepro_analysis_name="prepro_df",
    bad_channel_ids=None,
    artifact_frames_list=None,
    hyp_paths=None,
    hyp_artifactual_states=None,
    # Sorting
    sorting_analysis_name="ks2_5_nblocks=1_8s-batches",
    # misc
    rerun_existing=True,
    dry_run=False,
):

    # Check
    if not isinstance(tdt_folder_paths, (tuple, list)):
        raise ValueError(
            "`tdt_folder_paths` arg should be a list of existing TDT folders"
        )
    for tdt_folder in tdt_folder_paths:
        if not Path(tdt_folder).exists():
            raise FileNotFoundError(f"Could not find TDT folder `{tdt_folder}`")
    if t_end is None or not t_end:
        t_end = [None for _ in range(len(tdt_folder_paths))]
    else:
        if len(t_end) != len(tdt_folder_paths):
            raise ValueError(
                f"Expected `None` or a list of length {len(tdt_folder_paths)} for kwarg `t_end`"
            )
    if hyp_artifactual_states:
        if len(hyp_paths) != len(tdt_folder_paths):
            raise ValueError(
                f"`hyp_artifactual_states` kwarg was set: Expecting a list of length {len(tdt_folder_paths)} for kwarg `hyp_paths`"
            )
        if not all([Path(hyp_path).exists() for hyp_path in hyp_paths]):
            raise ValueError(
                f"`hyp_artifactual_states` kwarg was set: Could not find some of the hypnograms at the following paths:\n{hyp_paths}"
            )
    if hyp_paths is None or not hyp_paths:
        hyp_paths = [None for _ in range(len(tdt_folder_paths))]

    print(
        f"Running pipeline for TDT folder: {tdt_folder_paths}\n"
        f"End times for each block: {t_end}\n"
        f"Zero-ing out states `{hyp_artifactual_states}`\n"
        f"Hypno for each block: {hyp_paths}\n"
        f"Save all output at: {output_dir}"
    )

    # create output dir if it doesn't exist
    Path(output_dir).mkdir(exist_ok=True, parents=True)

    assert "NNX" in store
    if len(tdt_folder_paths) > 1 and artifact_frames_list is not None:
        # Should provide list of list if we concatenate
        raise NotImplementedError()

    # Load, preprocess each block, concatenate
    si_recordings = [
        load_and_preprocess_si_recording(
            tdt_folder,
            store=store,
            nchans=nchans,
            t_end=end_time,
            prepro_analysis_name=prepro_analysis_name,
            bad_channel_ids=bad_channel_ids,
            artifact_frames_list=artifact_frames_list,
            hyp_path=hyp_path,
            hyp_artifactual_states=hyp_artifactual_states,
            output_dir=output_dir,
        )
        for tdt_folder, end_time, hyp_path in zip(tdt_folder_paths, t_end, hyp_paths)
    ]
    
    concat_si_recording = si.core.concatenate_recordings(si_recordings)
    total_t = (
        concat_si_recording.get_num_frames()
        / concat_si_recording.get_sampling_frequency()
    )
    n_chans = concat_si_recording.get_num_channels()
    print(
        f"Concatenated N={len(si_recordings)} recordings. Total T={total_t}sec, n_chans={n_chans}"
    )
    return si_recordings, concat_si_recording
    # Run sorting
    print("\n\nRun sorting:")
    success = run_sorting(
        concat_si_recording,
        output_dir,
        sorting_analysis_name,
        rerun_existing=rerun_existing,
        dry_run=dry_run,
    )
    if not dry_run and not success:
        return False

    return True

# %%
tdt_folder_paths = [
            "/Volumes/opto_loc/Data/ACR_14/ACR_14-short1-iso/",
            "/Volumes/opto_loc/Data/ACR_14/ACR_14-short2-iso/",]
output_dir = "/nvme/sorting/tdt/ACR_14-shortiso-NNXr/"
store='NNXr'
t_end = [0, 0]

recs_r, cat_r = run_pipeline(tdt_folder_paths, output_dir, store=store, t_end=t_end)
# Out:
# Running pipeline for TDT folder: ['/Volumes/opto_loc/Data/ACR_14/ACR_14-short1-iso/', '/Volumes/opto_loc/Data/ACR_14/ACR_14-short2-iso/']
# End times for each block: [0, 0]
# Zero-ing out states `None`
# Hypno for each block: [None, None]
# Save all output at: /nvme/sorting/tdt/ACR_14-shortiso-NNXr/
# Load TDT block at /Volumes/opto_loc/Data/ACR_14/ACR_14-short1-iso/
# t_start = 0.0, t_end=0
# Load channel 1 from store NNXr, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 2 from store NNXr, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 3 from store NNXr, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 4 from store NNXr, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 5 from store NNXr, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 6 from store NNXr, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 7 from store NNXr, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 8 from store NNXr, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 9 from store NNXr, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 10 from store NNXr, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 11 from store NNXr, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 12 from store NNXr, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 13 from store NNXr, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 14 from store NNXr, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 15 from store NNXr, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 16 from store NNXr, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Saving nd-array loaded from TDT as tmp bin file at /nvme/sorting/tdt/ACR_14-shortiso-NNXr/tmp_bin_recording_ACR_14_ACR_14-short1-iso_NNXr_16_None_0
# Loading tmp bin file as BinaryRecordingExtractor
# Probe: Probe - 16ch - 1shanks
# Preprocessing:
# prepro params = {'bandpass_filter': None, 'remove_artifacts': {'ms_before': 20, 'ms_after': 20}}
# bad channels = None
# artifact frames = None
# Hypnogram states to zero-out = None
# Not zero-ing out any hypnogram bout
# Load TDT block at /Volumes/opto_loc/Data/ACR_14/ACR_14-short2-iso/
# t_start = 0.0, t_end=0
# Load channel 1 from store NNXr, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 2 from store NNXr, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 3 from store NNXr, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 4 from store NNXr, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 5 from store NNXr, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 6 from store NNXr, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 7 from store NNXr, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 8 from store NNXr, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 9 from store NNXr, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 10 from store NNXr, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 11 from store NNXr, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 12 from store NNXr, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 13 from store NNXr, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 14 from store NNXr, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 15 from store NNXr, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Load channel 16 from store NNXr, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# Saving nd-array loaded from TDT as tmp bin file at /nvme/sorting/tdt/ACR_14-shortiso-NNXr/tmp_bin_recording_ACR_14_ACR_14-short2-iso_NNXr_16_None_0
# Loading tmp bin file as BinaryRecordingExtractor
# Probe: Probe - 16ch - 1shanks
# Preprocessing:
# prepro params = {'bandpass_filter': None, 'remove_artifacts': {'ms_before': 20, 'ms_after': 20}}
# bad channels = None
# artifact frames = None
# Hypnogram states to zero-out = None
# Not zero-ing out any hypnogram bout
# Concatenated N=2 recordings. Total T=9759.8099456sec, n_chans=16

# %%
output_dir = "/nvme/sorting/tdt/ACR_14-shortiso-NNXr/"
success = run_sorting(
        cat_r,
        output_dir,
        "ks2_5_nblocks=1_8s-batches",
        rerun_existing=True,
        dry_run=False,
    )
# Out:
# Saving sorting output at /nvme/sorting/tdt/ACR_14-shortiso-NNXr/ks2_5_nblocks=1_8s-batches
# Running...Setting KILOSORT2_5_PATH environment variable for subprocess calls to: /Volumes/scratch/neuropixels/matlab/external/Kilosort-wisc-v2.5
# RUNNING SHELL SCRIPT: /tmp/tmp_shellscript557swag0/script.sh
# write_binary_recording: 100%|##########| 9760/9760 [00:11<00:00, 879.75it/s]
# RUNNING SHELL SCRIPT: /tmp/tmp_shellscriptdcxtyybd/script.sh
# RUNNING SHELL SCRIPT: /tmp/tmp_shellscriptrrk19s1v/script.sh
# RUNNING SHELL SCRIPT: /nvme/sorting/tdt/ACR_14-shortiso-NNXr/ks2_5_nblocks=1_8s-batches/run_kilosort2_5.sh
# Set Matlab shell to /usr/bin/bash
# fatal: detected dubious ownership in repository at '/Volumes/scratch/neuropixels/matlab/external/Kilosort-wisc-v2.5'
# To add an exception for this directory, call:
#
# 	git config --global --add safe.directory /Volumes/scratch/neuropixels/matlab/external/Kilosort-wisc-v2.5
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2019 The MathWorks, Inc.
#
#                   R2019b (9.7.0.1190202) 64-bit (glnxa64)
#
#                               August 21, 2019
#
#
#
#
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
#
#
# Setting latest mkl version
#
# Time   0s. Computing whitening matrix..
#
# Getting channel whitening matrix...
#
# Channel-whitening matrix computed.
#
# Time   4s. Loading raw data and applying filters...
#
# Time  72s. Finished preprocessing 909 batches.
#
# Drift correction ENABLED
#
# pitch is 50 um
#
# 0.09 sec, 1 batches, 4714 spikes
#
# 2.37 sec, 101 batches, 455764 spikes
#
# 4.62 sec, 201 batches, 880437 spikes
#
# 7.02 sec, 301 batches, 1502408 spikes
#
# 9.59 sec, 401 batches, 2261209 spikes
#
# 12.04 sec, 501 batches, 3004213 spikes
#
# 14.34 sec, 601 batches, 3550125 spikes
#
# 16.71 sec, 701 batches, 4004568 spikes
#
# 18.98 sec, 801 batches, 4447615 spikes
#
# 21.26 sec, 901 batches, 4877007 spikes
#
# 21.44 sec, 909 batches, 4921809 spikes
#
# Align block with original kilosort2.5 algorithm
#
# time 64.18, Shifted up/down 909 batches.
#
# Time  69s. Optimizing templates ...
#
# 69.43 sec, 1 / 909 batches, 3 units, nspks: 3.4654, mu: 15.1942, nst0: 7, merges: 0.0000, 0.0000, 0.1000
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In title (line 54)
#
#   In make_fig (line 26)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In matlab.graphics.internal.SubplotListenersManager>@(o,e)subplotlayout(ax,e,fig)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# 75.56 sec, 101 / 909 batches, 30 units, nspks: 588.7197, mu: 11.0754, nst0: 936, merges: 8.0782, 0.0000, 1.9495
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In matlab.graphics.internal.SubplotListenersManager>@(o,e)subplotlayout(ax,e,fig)
#
#   In learnTemplates (line 256)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In learnTemplates (line 256)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In learnTemplates (line 256)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In title (line 54)
#
#   In make_fig (line 26)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In matlab.graphics.internal.SubplotListenersManager>@(o,e)subplotlayout(ax,e,fig)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# 80.25 sec, 201 / 909 batches, 30 units, nspks: 716.9397, mu: 10.1920, nst0: 626, merges: 10.0728, 0.0000, 2.0794
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In title (line 54)
#
#   In make_fig (line 26)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In matlab.graphics.internal.SubplotListenersManager>@(o,e)subplotlayout(ax,e,fig)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# 85.19 sec, 301 / 909 batches, 33 units, nspks: 938.8393, mu: 10.8518, nst0: 803, merges: 10.5137, 0.0000, 2.3100
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In title (line 54)
#
#   In make_fig (line 26)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In matlab.graphics.internal.SubplotListenersManager>@(o,e)subplotlayout(ax,e,fig)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# 90.19 sec, 401 / 909 batches, 35 units, nspks: 883.1094, mu: 10.6248, nst0: 667, merges: 10.3962, 0.0000, 2.2704
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In title (line 54)
#
#   In make_fig (line 26)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In matlab.graphics.internal.SubplotListenersManager>@(o,e)subplotlayout(ax,e,fig)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# 95.31 sec, 501 / 909 batches, 33 units, nspks: 951.8349, mu: 10.4020, nst0: 1432, merges: 10.5590, 0.0000, 1.9983
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In title (line 54)
#
#   In make_fig (line 26)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In matlab.graphics.internal.SubplotListenersManager>@(o,e)subplotlayout(ax,e,fig)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# 100.68 sec, 601 / 909 batches, 41 units, nspks: 1118.0651, mu: 10.5832, nst0: 943, merges: 10.2865, 0.0000, 2.1815
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In title (line 54)
#
#   In make_fig (line 26)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In matlab.graphics.internal.SubplotListenersManager>@(o,e)subplotlayout(ax,e,fig)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# 106.68 sec, 701 / 909 batches, 62 units, nspks: 2056.3718, mu: 12.8102, nst0: 2317, merges: 8.6555, 0.0000, 2.0835
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In title (line 54)
#
#   In make_fig (line 26)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In matlab.graphics.internal.SubplotListenersManager>@(o,e)subplotlayout(ax,e,fig)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# 113.72 sec, 801 / 909 batches, 63 units, nspks: 2532.2441, mu: 17.9342, nst0: 2359, merges: 3.8797, 0.0000, 2.0896
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In title (line 54)
#
#   In make_fig (line 26)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In matlab.graphics.internal.SubplotListenersManager>@(o,e)subplotlayout(ax,e,fig)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# 123.50 sec, 901 / 909 batches, 64 units, nspks: 4455.1298, mu: 14.1734, nst0: 3612, merges: 4.0495, 0.0000, 1.9634
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In title (line 54)
#
#   In make_fig (line 26)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In matlab.graphics.internal.SubplotListenersManager>@(o,e)subplotlayout(ax,e,fig)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Elapsed time is 124.318343 seconds.
#
# Finished learning templates
#
# Time 124s. Optimizing templates ...
#
# 124.61 sec, 1 / 909 batches, 62 units, nspks: 1137.0000, mu: 12.9231, nst0: 5724
#
# 133.39 sec, 101 / 909 batches, 62 units, nspks: 92082.0000, mu: 12.9231, nst0: 4935
#
# 141.39 sec, 201 / 909 batches, 62 units, nspks: 162110.0000, mu: 12.9231, nst0: 5121
#
# 156.49 sec, 301 / 909 batches, 62 units, nspks: 400910.0000, mu: 12.9231, nst0: 11913
#
# 174.31 sec, 401 / 909 batches, 62 units, nspks: 725363.0000, mu: 12.9231, nst0: 4981
#
# 189.30 sec, 501 / 909 batches, 62 units, nspks: 962201.0000, mu: 12.9231, nst0: 3571
#
# 200.32 sec, 601 / 909 batches, 62 units, nspks: 1101934.0000, mu: 12.9231, nst0: 3276
#
# 208.68 sec, 701 / 909 batches, 62 units, nspks: 1178398.0000, mu: 12.9231, nst0: 5270
#
# 216.92 sec, 801 / 909 batches, 62 units, nspks: 1253155.0000, mu: 12.9231, nst0: 2593
#
# 225.13 sec, 901 / 909 batches, 62 units, nspks: 1328736.0000, mu: 12.9231, nst0: 3325
#
# Elapsed time is 226.347675 seconds.
#
# Number of spikes before applying cutoff: 5440868
#
# initialized spike counts
#
# Found 0 splits, checked 1/62 clusters, nccg 0
#
# Finished splitting. Found 7 splits, checked 69/69 clusters, nccg 0
#
# Removing 4.30139e+06 spikes below cutoff from rez.
#
# found 0 good units
#
# Saving results to Phy
#
# kilosort2_5 run time 362.95s
# 19:11:10: Finished /nvme/sorting/tdt/ACR_14-shortiso-NNXr/ks2_5_nblocks=1_8s-batches.
# Run time = 0:06:15.135898

# %%
tdt_folder_paths = [
            "/Volumes/opto_loc/Data/ACR_14/ACR_14-short1-iso/",
            "/Volumes/opto_loc/Data/ACR_14/ACR_14-short2-iso/",]
output_dir = "/nvme/sorting/tdt/ACR_14-shortiso-NNXo/"
store='NNXo'
t_end = [0, 0]

recs_o, cat_o = run_pipeline(tdt_folder_paths, output_dir, store=store, t_end=t_end)
# Out:
# Running pipeline for TDT folder: ['/Volumes/opto_loc/Data/ACR_14/ACR_14-short1-iso/', '/Volumes/opto_loc/Data/ACR_14/ACR_14-short2-iso/']
# End times for each block: [0, 0]
# Zero-ing out states `None`
# Hypno for each block: [None, None]
# Save all output at: /nvme/sorting/tdt/ACR_14-shortiso-NNXo/
# Load TDT block at /Volumes/opto_loc/Data/ACR_14/ACR_14-short1-iso/
# t_start = 0.0, t_end=0
# Load channel 1 from store NNXo, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 2 from store NNXo, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 3 from store NNXo, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 4 from store NNXo, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 5 from store NNXo, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 6 from store NNXo, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 7 from store NNXo, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 8 from store NNXo, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 9 from store NNXo, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 10 from store NNXo, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 11 from store NNXo, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 12 from store NNXo, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 13 from store NNXo, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 14 from store NNXo, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 15 from store NNXo, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 16 from store NNXo, read from t=0.0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Saving nd-array loaded from TDT as tmp bin file at /nvme/sorting/tdt/ACR_14-shortiso-NNXo/tmp_bin_recording_ACR_14_ACR_14-short1-iso_NNXo_16_None_0
# Loading tmp bin file as BinaryRecordingExtractor
# Probe: Probe - 16ch - 1shanks
# Preprocessing:
# prepro params = {'bandpass_filter': None, 'remove_artifacts': {'ms_before': 20, 'ms_after': 20}}
# bad channels = None
# artifact frames = None
# Hypnogram states to zero-out = None
# Not zero-ing out any hypnogram bout
# Load TDT block at /Volumes/opto_loc/Data/ACR_14/ACR_14-short2-iso/
# t_start = 0.0, t_end=0
# Load channel 1 from store NNXo, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 2 from store NNXo, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 3 from store NNXo, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 4 from store NNXo, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 5 from store NNXo, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 6 from store NNXo, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 7 from store NNXo, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 8 from store NNXo, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 9 from store NNXo, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 10 from store NNXo, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 11 from store NNXo, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 12 from store NNXo, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 13 from store NNXo, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 14 from store NNXo, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 15 from store NNXo, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Load channel 16 from store NNXo, read from t=0.0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Saving nd-array loaded from TDT as tmp bin file at /nvme/sorting/tdt/ACR_14-shortiso-NNXo/tmp_bin_recording_ACR_14_ACR_14-short2-iso_NNXo_16_None_0
# Loading tmp bin file as BinaryRecordingExtractor
# Probe: Probe - 16ch - 1shanks
# Preprocessing:
# prepro params = {'bandpass_filter': None, 'remove_artifacts': {'ms_before': 20, 'ms_after': 20}}
# bad channels = None
# artifact frames = None
# Hypnogram states to zero-out = None
# Not zero-ing out any hypnogram bout
# Concatenated N=2 recordings. Total T=9759.8099456sec, n_chans=16

# %%
output_dir = "/nvme/sorting/tdt/ACR_14-shortiso-NNXo/"
success = run_sorting(
        cat_o,
        output_dir,
        "ks2_5_nblocks=1_8s-batches",
        rerun_existing=True,
        dry_run=False,
    )
# Out:
# Saving sorting output at /nvme/sorting/tdt/ACR_14-shortiso-NNXo/ks2_5_nblocks=1_8s-batches
# Running...Setting KILOSORT2_5_PATH environment variable for subprocess calls to: /Volumes/scratch/neuropixels/matlab/external/Kilosort-wisc-v2.5
# RUNNING SHELL SCRIPT: /tmp/tmp_shellscriptr937sk16/script.sh
# write_binary_recording: 100%|##########| 9760/9760 [00:11<00:00, 884.99it/s]
# RUNNING SHELL SCRIPT: /tmp/tmp_shellscript16go124m/script.sh
# RUNNING SHELL SCRIPT: /tmp/tmp_shellscript0lf49zj5/script.sh
# RUNNING SHELL SCRIPT: /nvme/sorting/tdt/ACR_14-shortiso-NNXo/ks2_5_nblocks=1_8s-batches/run_kilosort2_5.sh
# Set Matlab shell to /usr/bin/bash
# fatal: detected dubious ownership in repository at '/Volumes/scratch/neuropixels/matlab/external/Kilosort-wisc-v2.5'
# To add an exception for this directory, call:
#
# 	git config --global --add safe.directory /Volumes/scratch/neuropixels/matlab/external/Kilosort-wisc-v2.5
#                             < M A T L A B (R) >
#
#                   Copyright 1984-2019 The MathWorks, Inc.
#
#                   R2019b (9.7.0.1190202) 64-bit (glnxa64)
#
#                               August 21, 2019
#
#
#
#
#
# To get started, type doc.
#
# For product information, visit www.mathworks.com.
#
#
#
# Setting latest mkl version
#
# Time   0s. Computing whitening matrix..
#
# Getting channel whitening matrix...
#
# Channel-whitening matrix computed.
#
# Time   4s. Loading raw data and applying filters...
#
# Time  73s. Finished preprocessing 909 batches.
#
# Drift correction ENABLED
#
# pitch is 50 um
#
# 0.07 sec, 1 batches, 2329 spikes
#
# 2.37 sec, 101 batches, 216821 spikes
#
# 4.67 sec, 201 batches, 418725 spikes
#
# 7.01 sec, 301 batches, 657128 spikes
#
# 9.33 sec, 401 batches, 922731 spikes
#
# 11.72 sec, 501 batches, 1215419 spikes
#
# 14.05 sec, 601 batches, 1460089 spikes
#
# 16.36 sec, 701 batches, 1688925 spikes
#
# 18.69 sec, 801 batches, 1910523 spikes
#
# 21.10 sec, 901 batches, 2123662 spikes
#
# 21.28 sec, 909 batches, 2139767 spikes
#
# Align block with original kilosort2.5 algorithm
#
# time 57.94, Shifted up/down 909 batches.
#
# Time  63s. Optimizing templates ...
#
# 63.06 sec, 1 / 909 batches, 4 units, nspks: 4.9396, mu: 16.9792, nst0: 15, merges: 0.0000, 0.0000, 0.2000
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In title (line 54)
#
#   In make_fig (line 26)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In matlab.graphics.internal.SubplotListenersManager>@(o,e)subplotlayout(ax,e,fig)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# 70.34 sec, 101 / 909 batches, 31 units, nspks: 2238.3468, mu: 11.3271, nst0: 2297, merges: 7.8371, 0.0000, 1.7897
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In matlab.graphics.internal.SubplotListenersManager>@(o,e)subplotlayout(ax,e,fig)
#
#   In learnTemplates (line 256)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In learnTemplates (line 256)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In learnTemplates (line 256)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In title (line 54)
#
#   In make_fig (line 26)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In matlab.graphics.internal.SubplotListenersManager>@(o,e)subplotlayout(ax,e,fig)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# 77.52 sec, 201 / 909 batches, 37 units, nspks: 2359.8692, mu: 11.5853, nst0: 1782, merges: 9.6370, 0.0387, 1.9741
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In title (line 54)
#
#   In make_fig (line 26)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In matlab.graphics.internal.SubplotListenersManager>@(o,e)subplotlayout(ax,e,fig)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# 84.54 sec, 301 / 909 batches, 47 units, nspks: 2262.5292, mu: 11.0094, nst0: 2755, merges: 9.4430, 0.0276, 1.8585
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In title (line 54)
#
#   In make_fig (line 26)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In matlab.graphics.internal.SubplotListenersManager>@(o,e)subplotlayout(ax,e,fig)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# 91.24 sec, 401 / 909 batches, 48 units, nspks: 2004.2372, mu: 10.8786, nst0: 1874, merges: 9.5317, 0.0423, 1.8965
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In title (line 54)
#
#   In make_fig (line 26)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In matlab.graphics.internal.SubplotListenersManager>@(o,e)subplotlayout(ax,e,fig)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# 97.53 sec, 501 / 909 batches, 46 units, nspks: 1735.5200, mu: 10.9837, nst0: 2116, merges: 9.9289, 0.0768, 1.8698
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In title (line 54)
#
#   In make_fig (line 26)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In matlab.graphics.internal.SubplotListenersManager>@(o,e)subplotlayout(ax,e,fig)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# 103.94 sec, 601 / 909 batches, 50 units, nspks: 2008.2040, mu: 10.7901, nst0: 1754, merges: 9.5550, 0.1143, 1.9760
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In title (line 54)
#
#   In make_fig (line 26)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In matlab.graphics.internal.SubplotListenersManager>@(o,e)subplotlayout(ax,e,fig)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# 110.23 sec, 701 / 909 batches, 51 units, nspks: 1858.5831, mu: 11.0000, nst0: 1699, merges: 10.8058, 0.0730, 2.3442
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In title (line 54)
#
#   In make_fig (line 26)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In matlab.graphics.internal.SubplotListenersManager>@(o,e)subplotlayout(ax,e,fig)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# 116.38 sec, 801 / 909 batches, 57 units, nspks: 1577.3993, mu: 11.3276, nst0: 1510, merges: 9.6630, 0.1540, 2.2868
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In title (line 54)
#
#   In make_fig (line 26)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In matlab.graphics.internal.SubplotListenersManager>@(o,e)subplotlayout(ax,e,fig)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# 122.49 sec, 901 / 909 batches, 47 units, nspks: 1562.6050, mu: 10.7020, nst0: 1357, merges: 10.4183, 0.0470, 2.0188
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In title (line 54)
#
#   In make_fig (line 26)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In xlabel (line 56)
#
#   In make_fig (line 27)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In ylabel (line 56)
#
#   In make_fig (line 28)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In matlab.graphics.internal.SubplotListenersManager>@(o,e)subplotlayout(ax,e,fig)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Warning: Error updating Axes.
#
#
#
#  Cannot untransform a point, matrix may be invalid or singular
#
#
#
# > In defaulterrorcallback (line 12)
#
#   In make_fig (line 29)
#
#   In learnTemplates (line 258)
#
#   In learnAndSolve8b (line 35)
#
#   In kilosort2_5_master (line 45)
#
# Elapsed time is 123.038341 seconds.
#
# Finished learning templates
#
# Time 123s. Optimizing templates ...
#
# 123.28 sec, 1 / 909 batches, 45 units, nspks: 2104.0000, mu: 10.7103, nst0: 6248
#
# 133.70 sec, 101 / 909 batches, 45 units, nspks: 196893.0000, mu: 10.7103, nst0: 5668
#
# 143.68 sec, 201 / 909 batches, 45 units, nspks: 378637.0000, mu: 10.7103, nst0: 6291
#
# 155.20 sec, 301 / 909 batches, 45 units, nspks: 599204.0000, mu: 10.7103, nst0: 6818
#
# 168.10 sec, 401 / 909 batches, 45 units, nspks: 858770.0000, mu: 10.7103, nst0: 7039
#
# 181.23 sec, 501 / 909 batches, 45 units, nspks: 1127839.0000, mu: 10.7103, nst0: 6598
#
# 191.59 sec, 601 / 909 batches, 45 units, nspks: 1320916.0000, mu: 10.7103, nst0: 5671
#
# 201.46 sec, 701 / 909 batches, 45 units, nspks: 1508430.0000, mu: 10.7103, nst0: 4123
#
# 211.41 sec, 801 / 909 batches, 45 units, nspks: 1693553.0000, mu: 10.7103, nst0: 4378
#
# 220.99 sec, 901 / 909 batches, 45 units, nspks: 1873486.0000, mu: 10.7103, nst0: 4365
#
# Elapsed time is 221.702227 seconds.
#
# Number of spikes before applying cutoff: 5422151
#
# initialized spike counts
#
# merged 20 into 21
#
# Found 0 splits, checked 1/45 clusters, nccg 0
#
# Finished splitting. Found 4 splits, checked 49/49 clusters, nccg 5
#
# Removing 3.72442e+06 spikes below cutoff from rez.
#
# found 3 good units
#
# Saving results to Phy
#
# kilosort2_5 run time 361.92s
# 19:17:24: Finished /nvme/sorting/tdt/ACR_14-shortiso-NNXo/ks2_5_nblocks=1_8s-batches.
# Run time = 0:06:14.164604

# %%
cat_r.get_num_frames()
cat_o.get_num_frames()
cat_r.get_num_samples()
cat_o.get_num_samples()
# Out:
# 238276610

# %%
sorto = se.KiloSortSortingExtractor("/nvme/sorting/tdt/ACR_14-shortiso-NNXo/ks2_5_nblocks=1_8s-batches/")
sortp = se.KiloSortSortingExtractor("/nvme/sorting/tdt/ACR_14-shortiso-NNXr/ks2_5_nblocks=1_8s-batches/")

# %%
(sorto.get_all_spike_trains()[0][0]/24414.06)[-1]
# Out:
# 9759.795052523014

# %%
(sortp.get_all_spike_trains()[0][0]/24414.06)[-1]
# Out:
# 9759.810371564581

# %%
p1 = '/Volumes/opto_loc/Data/ACR_14/ACR_14-short1-iso/'
p2 = '/Volumes/opto_loc/Data/ACR_14/ACR_14-short2-iso/'

d1 = tdt.read_block(p1, store=['NNXr', 'NNXo'], channel=[2, 16])
d2 = tdt.read_block(p2, store=['NNXr', 'NNXo'], channel=[2, 16])
# Out:
# read from t=0s to t=6426.9s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Using 24414.0625 Hz as SEV sampling rate for NNXr
# read from t=0s to t=3333.13s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Using 24414.0625 Hz as SEV sampling rate for NNXr

# %%
p2 = '/Volumes/opto_loc/Data/ACR_14/ACR_14-short2-iso/'

dd1 = tdt.read_block(p2, store=['NNXr', 'NNXo'], channel=[1], t1=0, t2=1)
# Out:
# read from t=0s to t=950.14s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Using 24414.0625 Hz as SEV sampling rate for NNXr

# %%
len(dd1.streams.NNXo.data)
# Out:
# 24415

# %%
d1.info
# Out:
# tankpath:	'/Volumes/opto_loc/Data/ACR_14'
# blockname:	'ACR_14-short1-iso'
# start_date:	datetime.datetime(2022, 9, 30, 12, 8, 22, 999999)
# utc_start_time:	'12:08:22'
# stop_date:	datetime.datetime(2022, 9, 30, 13, 55, 29, 901070)
# utc_stop_time:	'13:55:29'
# duration:	datetime.timedelta(seconds=6426, microseconds=901071)
# stream_channel:	[2, 16]
# snip_channel:	[2, 16]

# %%
d2.info
# Out:
# tankpath:	'/Volumes/opto_loc/Data/ACR_14'
# blockname:	'ACR_14-short2-iso'
# start_date:	datetime.datetime(2022, 9, 30, 13, 55, 38, 999999)
# utc_start_time:	'13:55:38'
# stop_date:	datetime.datetime(2022, 9, 30, 14, 51, 12, 130175)
# utc_stop_time:	'14:51:12'
# duration:	datetime.timedelta(seconds=3333, microseconds=130176)
# stream_channel:	[2, 16]
# snip_channel:	[2, 16]

# %%
d1.streams.NNXr
# Out:
# channels:	[2, 16]
# data:	array([[-4.4031996e-05, -3.8015998e-05, -4.9279995e-05, ...,
#          1.8220799e-04,  1.9417598e-04,  0.0000000e+00],
#        [-2.3039998e-05, -3.3407996e-05, -2.7199998e-05, ...,
#          9.2223997e-04,  9.1846392e-04,  0.0000000e+00]], dtype=float32)
# name:	'NNXr'
# fs:	24414.0625
# start_time:	0.0

# %%
d2.streams.NNXr.data[0]
# Out:
# (81371137,)

# %%
156905473/d1.streams.NNXr.fs
# Out:
# 6426.84817408

# %%
d1.streams.NNXo.data[0].shape
# Out:
# (156905473,)

# %%
subject = 'ACR_14'

# %%
op = '/Volumes/opto_loc/Data/ACR_14/sorting_data/sdpi-NNXo/ks2_5_nblocks=1_8s-batches/'
pp = '/Volumes/opto_loc/Data/ACR_14/sorting_data/sdpi-NNXr/ks2_5_nblocks=1_8s-batches/'
o = se.KiloSortSortingExtractor(op)
p = se.KiloSortSortingExtractor(pp)
ot = (o.get_all_spike_trains()[0][0]/24414.06)[-1]
pt = (p.get_all_spike_trains()[0][0]/24414.06)[-1]

print('Final Spike Time, Probe-1', pt)
print('Final Spike Time, Probe-2 (optrode):', ot)
# Out:
# Final Spike Time, Probe-1 257066.63221930314
# Final Spike Time, Probe-2 (optrode): 257066.62816426271

# %%
'theoretical length of concatenated recording: '+str(86495+85777.12390144+84794.5806)
# Out:
# 'theoretical length of concatenated recording: 257066.70450144'

# %%
op = '/Volumes/opto_loc/Data/ACR_14/sorting_data/laser1-NNXo/ks2_5_nblocks=1_8s-batches/'
pp = '/Volumes/opto_loc/Data/ACR_14/sorting_data/laser1-NNXr/ks2_5_nblocks=1_8s-batches/'
o = se.KiloSortSortingExtractor(op)
p = se.KiloSortSortingExtractor(pp)
ot = (o.get_all_spike_trains()[0][0]/24414.06)[-1]
pt = (p.get_all_spike_trains()[0][0]/24414.06)[-1]

print('Final Spike Time, Probe-1', pt)
print('Final Spike Time, Probe-2 (optrode):', ot)
# Out:
# Final Spike Time, Probe-1 130886.94260602292
# Final Spike Time, Probe-2 (optrode): 130897.00901857372

# %%
'theoretical length of concatenated recording: '+str(37450+50151.29296896+43295.70308096)
# Out:
# 'theoretical length of concatenated recording: 130896.99604992'

# %%
op = '/Volumes/opto_loc/Data/ACR_14/sorting_data/swi-NNXo/ks2_5_nblocks=1_8s-batches/'
pp = '/Volumes/opto_loc/Data/ACR_14/sorting_data/swi-NNXr/ks2_5_nblocks=1_8s-batches/'
o = se.KiloSortSortingExtractor(op)
p = se.KiloSortSortingExtractor(pp)
ot = (o.get_all_spike_trains()[0][0]/24414.06)[-1]
pt = (p.get_all_spike_trains()[0][0]/24414.06)[-1]

print('Final Spike Time, Probe-1', pt)
print('Final Spike Time, Probe-2 (optrode):', ot)
# Out:
# Final Spike Time, Probe-1 177735.244199449
# Final Spike Time, Probe-2 (optrode): 177725.08972288918

# %%
'theoretical length of concatenated recording: '+str(73385.907709+86464.616425+17884.876654)
# Out:
# 'theoretical length of concatenated recording: 177735.400788'

# %%
path = '/Volumes/opto_loc/Data/ACR_14/ACR_14-laser1/'
laser1 = tdt.read_block(path, store=['NNXr', 'NNXo'], channel=[1], t1=0, t2=1)
# Out:
# read from t=0s to t=856.79s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Using 24414.0625 Hz as SEV sampling rate for NNXr

# %%
path = '/Volumes/opto_loc/Data/ACR_14/ACR_14-swi/'
swi = tdt.read_block(path, store=['NNXr', 'NNXo'], channel=[1], t1=0, t2=1)
# Out:
# read from t=0s to t=791.83s
# Using 24414.0625 Hz as SEV sampling rate for NNXo
# Using 24414.0625 Hz as SEV sampling rate for NNXr
